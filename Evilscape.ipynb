# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.colors as mcolors
from matplotlib.animation import FuncAnimation

from IPython.display import HTML

# Set the limit to, for example, 100 MB
plt.rcParams['animation.embed_limit'] = 100
# %matplotlib inline

import numpy as np
import random
import pandas as pd
import time

#import warnings
#warnings.filterwarnings('ignore', category=FutureWarning)

# %%
class Environment:
    def __init__(self, size, max_capacity=4, agent_vision_range=(1, 6), agent_metabolism_range=(1, 4), enable_seasons=True, tau=0.5, d=0.1):
        self.size = size
        self.enable_seasons = enable_seasons  # Control seasonal effects
        self.eco_crisis = []  # Store active ecological evils here
        self.active_diseases = []  # Initialize the list for active diseases
        self.tau = tau  # Resource allocation bias
        self.d = d  # Ensure d is a float for deadweight loss

        self.max_capacity = max_capacity
        self.agent_vision_range = agent_vision_range
        self.agent_metabolism_range = agent_metabolism_range
        
        self.northern_mountain_cells = []  # Stores coordinates of cells in the northern mountain
        self.southern_mountain_cells = []  # Stores coordinates of cells in the southern mountain
        
        # Initialization of other attributes...
        self.grid = np.zeros(size, dtype=int)
        self.max_sugar_capacity = np.zeros(size, dtype=int)
        self.initialize_sugar_capacity(max_capacity)
        self.initialize_sugar()
        self.agents = []
        self.occupied_locations = set()
        self.history = [np.copy(self.grid)]
        self.agents_history = []  # Make sure this is initialized here
        
        # Season tracking
        self.current_step = 0
        self.season_length = 50
        # Initially, northern half starts in summer, southern in winter
        self.northern_summer = True
        
        # Initialize counters
        self.replacements = 0
        self.deaths_due_to_age = 0
        self.deaths_due_to_starvation = 0

    def initialize_sugar_capacity(self, max_capacity):
        """Defines the maximum sugar capacity for each cell, including mountains."""
        # Initialize all cells with a default capacity
        self.max_sugar_capacity.fill(0)  # Assuming wasteland has minimal sugar

        # Define peaks for the sugar mountains
        peak1 = (int(self.size[0] / 4), int(self.size[1] / 4))  # Northern peak
        peak2 = (int(3 * self.size[0] / 4), int(3 * self.size[1] / 4))  # Southern peak

        # Define the sugar mountains
        for i in range(self.size[0]):
            for j in range(self.size[1]):
                distance1 = np.sqrt((i - peak1[0])**2 + (j - peak1[1])**2)
                distance2 = np.sqrt((i - peak2[0])**2 + (j - peak2[1])**2)

                # Determine if the cell is closer to the northern or southern peak
                if distance1 < distance2:
                    self.northern_mountain_cells.append((i, j))
                else:
                    self.southern_mountain_cells.append((i, j))

                # The further from the peak, the lower the maximum capacity
                capacity1 = max(max_capacity - int(distance1 / 3), 0)
                capacity2 = max(max_capacity - int(distance2 / 3), 0)

                # Assign the higher of the two capacities, capped at max_capacity
                self.max_sugar_capacity[i, j] = min(max(capacity1, capacity2), max_capacity)

    def initialize_sugar(self):
        """Initializes the grid with sugar according to max capacity."""
        self.grid = np.copy(self.max_sugar_capacity)  # Start with the max capacity as initial sugar levels

    def grow_sugar(self):
        """Simulates the regrowth of sugar on the grid, respecting each cell's max capacity."""
        # Reset grid for non-seasonal growth or inactive mountain areas
        self.grid = np.zeros(self.size, dtype=int)  # Resetting to zero if you want to simulate 'dying off'

        severity = 0  # Default to no crisis effect if none are active
        for evil in self.eco_crisis:
            if evil.active:
                severity = max(severity, evil.severity)  # Assume the worst severity applies

        """
        Simulates the regrowth of sugar on the grid, respecting each cell's max capacity and considering seasonality.
        Each cell can grow by 1 unit per step up to its adjusted (seasonal) maximum capacity.
        """    
        if self.enable_seasons:
            active_mountain_cells = self.northern_mountain_cells if self.northern_summer else self.southern_mountain_cells
            for x, y in active_mountain_cells:
                # Ensure the adjusted max sugar capacity doesn't drop below zero
                adjusted_max_capacity = max(self.max_sugar_capacity[y, x] - severity, 0)
                self.grid[y, x] = min(self.grid[y, x] + 6, adjusted_max_capacity)
        else:
            for y in range(self.size[1]):
                for x in range(self.size[0]):
                    # Ensure the adjusted max sugar capacity doesn't drop below zero
                    adjusted_max_capacity = max(self.max_sugar_capacity[y, x] - severity, 0)
                    self.grid[y, x] = min(self.grid[y, x] + 6, adjusted_max_capacity)
        
    def switch_seasons(self):
        if self.enable_seasons and self.current_step % self.season_length == 0:
            self.northern_summer = not self.northern_summer

    def update_eco_crisis(self):
        """Updates the status of all active ecological evils."""
        for crisis in list(self.eco_crisis):  # Use a copy of the list for safe modification
            if crisis.active:
                crisis.duration -= 1
                if crisis.duration <= 0:
                    crisis.deactivate()
                    self.eco_crisis.remove(crisis)
    
    def trigger_crisis(self, crisis):
        """Activates and adds an evil to the environment."""
        crisis.activate()
        self.eco_crisis.append(crisis)
    
    def update_diseases(self):
        """Updates the status of all active diseases."""
        for disease in list(self.active_diseases):
            if disease.active:
                disease.update(self)
                if disease.is_over():
                    disease.deactivate()
                    self.active_diseases.remove(disease)

    def trigger_disease(self, disease):
        """Activates a disease and initially infects a random agent if possible."""
        disease.activate()
        if disease.active:  # Only proceed if the disease is successfully activated
            self.active_diseases.append(disease)
            if self.agents:  # Ensure there are agents to infect
                initial_infected_agent = random.choice(self.agents)
                initial_infected_agent.infect(disease.severity, disease.duration)
    
    def capture_agents_initial_data(self):
        """Captures the initial data of all agents."""
        # Make sure this method is called after all agents are added
        self.agents_history.append([(agent.location, agent.type, agent.sugar, agent.metabolism, agent.vision, agent.age, agent.is_infected, agent.alive) for agent in self.agents])

    def add_agent(self, agent):
        self.agents.append(agent)
        self.occupied_locations.add(agent.location)

    def remove_agent(self, agent):
        """Removes an agent from the simulation."""
        self.agents.remove(agent)
        self.occupied_locations.discard(agent.location)

    def is_occupied(self, location):
        """Checks if a location is occupied by an agent."""
        return location in self.occupied_locations

    def move_agent(self, agent, new_location):
        """Moves an agent to a new location within the grid."""
        self.occupied_locations.discard(agent.location)
        agent.location = new_location
        self.occupied_locations.add(new_location)

    def harvest_sugar(self, location):
        """Allows an agent to harvest sugar from its current location."""
        sugar = self.grid[location]
        self.grid[location] = 0
        return sugar

    def generate_random_unoccupied_location(self):
        """Finds a random unoccupied location within the environment."""
        while True:
            location = (np.random.randint(0, self.size[0]), np.random.randint(0, self.size[1]))
            if not self.is_occupied(location):
                return location
    
    def find_adjacent_unoccupied_location(self, location):
        directions = [(-1, 0), (1, 0), (0, -1), (0, 1)]  # Up, down, left, right
        random.shuffle(directions)  # Randomize directions to avoid bias
        for dx, dy in directions:
            new_x = (location[0] + dx) % self.size[0]
            new_y = (location[1] + dy) % self.size[1]
            new_location = (new_x, new_y)
            if not self.is_occupied(new_location):
                return new_location
        return None  # No unoccupied adjacent locations available
    
    def get_von_neumann_neighbors(self, location):
        """Returns the Von Neumann neighbors (up, down, left, right) of a given location."""
        x, y = location
        neighbors = []
        directions = [(-1, 0), (1, 0), (0, -1), (0, 1)]  # Up, down, left, right
        for dx, dy in directions:
            nx, ny = (x + dx) % self.size[0], (y + dy) % self.size[1]
            if self.is_occupied((nx, ny)):
                neighbor = self.get_agent_at((nx, ny))
                if neighbor:
                    neighbors.append(neighbor)
        return neighbors

    def get_agent_at(self, location):
        """Returns the agent at the specified location, if any."""
        for agent in self.agents:
            if agent.location == location:
                return agent
        return None
    
    def play_resource_game(self, agent1, agent2):

        total_resources = agent1.sugar + agent2.sugar
        adjusted_resources = round(total_resources * (1 - self.d))  # Account for deadweight loss when both are selfish, and round it

        if agent1.type == agent2.type:
            # Homogeneous pair (either both altruistic or both selfish)
            if agent1.type == "selfish":
                agent1.sugar = round(adjusted_resources / 2)
                agent2.sugar = round(adjusted_resources / 2)
            else:
                agent1.sugar = round(total_resources / 2)
                agent2.sugar = round(total_resources / 2)
        else:
            # Heterogeneous pair (one altruistic, one selfish)
            if agent1.type == "selfish":
                agent1.sugar = round(total_resources / 2 + self.tau * total_resources)
                agent2.sugar = round(total_resources / 2 - self.tau * total_resources)
            else:
                agent1.sugar = round(total_resources / 2 - self.tau * total_resources)
                agent2.sugar = round(total_resources / 2 + self.tau * total_resources)

        # Ensure that sugar does not drop below zero due to rounding errors
        agent1.sugar = max(0, agent1.sugar)
        agent2.sugar = max(0, agent2.sugar)
    
    def step(self):
        """Advances the simulation by one step, including managing eco crises and diseases."""
        self.current_step += 1
        self.switch_seasons()
        self.update_eco_crisis()
        self.update_diseases()  # Make sure diseases are updated each step
        self.grow_sugar()

        random.shuffle(self.agents)

        for agent in list(self.agents):
            if not agent.alive:
                continue  # Skip dead agents for processing
            
            agent_initial_sugar = agent.sugar
            agent.step(self)  # Internal agent state management including disease effects
            
            # Play the resource game with neighboring agents
            neighbors = self.get_von_neumann_neighbors(agent.location)
            for neighbor in neighbors:
                self.play_resource_game(agent, neighbor)

            if agent.sugar < 1 and agent_initial_sugar > 0:
                self.deaths_due_to_starvation += 1
            if agent.age > agent.max_age:
                self.deaths_due_to_age += 1

        self.update_visualization_and_data()

    def update_visualization_and_data(self):
        """Updates the state of the grid and agents for visualization and collects data."""
        # Store the current grid state in history
        self.history.append(np.copy(self.grid))

        # Store the current state of agents in agents_history
        current_agents_state = [
            (
                agent.location,
                agent.type,
                agent.sugar,
                agent.metabolism,
                agent.vision,
                agent.age,
                agent.is_infected,
                agent.alive  # Include alive status
            ) for agent in self.agents
        ]
        # Collect data from the current agents state, which includes both living and dead agents at this step
        self.agents_history.append(current_agents_state)

# %%
class Agent:
    def __init__(self, location, sugar=20, metabolism=1, vision=2, max_age=100, age=0, type=None):
        self.location = location
        self.sugar = sugar
        self.original_metabolism = metabolism  # Store original metabolism for disease effect
        self.metabolism = max(1, metabolism)
        self.vision = max(1, vision)
        self.age = age
        self.max_age = max_age
        self.alive = True  # Initialize the agent as alive
        self.is_infected = False
        self.infection_duration = 0
        self.disease_severity = 0
        self.is_immune = False  # Track immunity status
        self.just_infected = False  # Track if just infected in the current step
        self.just_recovered = False  # Track if just recovered in the current step
        self.death_cause = None  # Initialize with None
        
        # Assign type randomly if not provided, otherwise use the provided type
        self.type = type if type is not None else np.random.choice(["selfish", "altruistic"])

    def infect(self, severity, duration):
        if severity > 0 and duration > 0 and not self.is_immune and not self.is_infected:
            self.is_infected = True
            self.disease_severity = severity
            self.infection_duration = duration
            self.just_infected = True  # Mark as just infected
            self.adjust_metabolism()

    def adjust_metabolism(self):
        if self.is_infected:
            self.metabolism = 4 * self.original_metabolism

    def manage_disease(self):
        if self.is_infected:
            self.infection_duration -= 1
            if self.infection_duration <= 0:
                self.recover()

    def recover(self):
        self.is_infected = False
        self.just_recovered = True  # Mark as just recovered
        self.reset_metabolism()
        self.is_immune = True  # Grant immunity after recovery

    def reset_metabolism(self):
        self.metabolism = self.original_metabolism
        
    def check_and_infect_neighbors(self, neighbors, severity):
        """Check neighboring agents and potentially infect them based on disease severity."""
        if self.is_infected:  # Only spread the disease if this agent is infected
            for neighbor in neighbors:
                if not neighbor.is_immune and not neighbor.is_infected:
                    infection_chance = random.random()
                    if infection_chance < severity:
                        neighbor.infect(severity, self.infection_duration)
                else:
                    status = 'immune' if neighbor.is_immune else 'already infected'
                    # This else block now does nothing with 'status', but you can use it for debugging if needed
                    
    def look_around(self, environment):
        """
        Agent decides where to move based on the surrounding sugar.
        """
        best_sugar_level = -1
        best_location = self.location

        # Explore surrounding cells within vision
        for dx in range(-self.vision, self.vision + 1):
            for dy in range(-self.vision, self.vision + 1):
                if dx == 0 and dy == 0:
                    continue  # Skip the agent's current location

                # Calculate the target location, considering wrap-around
                target_x = (self.location[0] + dx) % environment.size[0]
                target_y = (self.location[1] + dy) % environment.size[1]
                target_location = (target_x, target_y)

                # Ensure the target location is not occupied and within the grid
                if not environment.is_occupied(target_location):
                    sugar_level = environment.grid[target_location]
                    if sugar_level > best_sugar_level:
                        best_sugar_level = sugar_level
                        best_location = target_location

        return best_location

    def move(self, environment, new_location):
        """
        Moves the agent to a new location.
        """
        environment.move_agent(self, new_location)

    def harvest(self, environment):
        """
        Harvests sugar from the current location.
        """
        self.sugar += environment.harvest_sugar(self.location)

    def step(self, environment):
        if not self.alive:  # Skip processing for dead agents
            return

        # Reset infection and recovery markers at the beginning of each step
        self.just_infected = False
        self.just_recovered = False

        # Aging and checking for natural death due to old age
        self.age += 1
        if self.age > self.max_age:
            self.alive = False
            self.death_cause = 'age'
            environment.remove_agent(self)
            return

        # Disease management within the step function
        if self.is_infected:
            self.manage_disease()

        # Check for death due to running out of sugar
        if self.sugar <= 0:
            self.alive = False
            self.death_cause = 'starvation'
            environment.remove_agent(self)
            return

        # Movement and harvesting if alive
        if self.alive:
            new_location = self.look_around(environment)
            if new_location != self.location:
                self.move(environment, new_location)
            self.harvest(environment)

        # Subtract metabolism and check for death due to starvation
        self.sugar -= self.metabolism
        if self.sugar <= 0:
            self.alive = False
            self.death_cause = 'starvation'
            environment.remove_agent(self)
            return

        # Reproduction attempt only if still alive and conditions are met
        if self.alive:
            self.try_to_reproduce(environment)

    def try_to_reproduce(self, environment):
        # Set different sugar thresholds based on infection status
        sugar_threshold = 99 if self.is_infected else 49

        if self.age > 11 and self.age < 51 and self.sugar > sugar_threshold:
            new_location = environment.find_adjacent_unoccupied_location(self.location)
            if new_location:
                offspring = self.reproduce(new_location, environment)
                if offspring:  # Check if reproduction was successful
                    environment.add_agent(offspring)

    def reproduce(self, new_location, environment):
        # Adjust the sugar cost and offspring's sugar based on infection status
        if self.is_infected:
            reproduction_sugar_cost = int(0.75 * self.sugar)
            offspring_sugar = self.sugar // 10
        else:
            reproduction_sugar_cost = self.sugar // 2
            offspring_sugar = self.sugar // 5

        # Only proceed with reproduction if there's enough sugar
        if self.sugar > reproduction_sugar_cost:
            self.sugar -= reproduction_sugar_cost  # Parent loses sugar based on infection status

            # Define specific mutation functions for each attribute
            mutate_metabolism = lambda x: max(1, x + random.choice([-1, 0, 1]))
            mutate_vision = lambda x: max(1, x + random.choice([-2, 0, 2]))
            mutate_max_age = lambda x: x + random.choice([-5, 0, 5])

            # Apply these mutations to create offspring
            offspring = Agent(
                    location=new_location,
                    sugar=offspring_sugar,
                    metabolism=mutate_metabolism(self.metabolism),
                    vision=mutate_vision(self.vision),
                    max_age=mutate_max_age(self.max_age),
                    age=0,  # Newborn starts at age 0
                    type=self.type  # Inherit type from the parent
            )
            return offspring
        else:
            # Not enough sugar to reproduce, return None or similar to indicate failure
            return None

# %%
class EcoCrisis:
    def __init__(self, severity=0, duration=0, frequency=1):
        self.severity = severity
        self.duration = duration
        self.active = False  # Track whether the evil is currently active

    def activate(self):
        if self.severity > 0 and self.duration > 0:
            self.active = True
            # print(f"Crisis activated with severity {self.severity} and duration {self.duration}")
        else:
            # print("Crisis parameters set to zero, not activating disease.")
            pass

    def deactivate(self):
        self.active = False  # Mark the evil as inactive

    def apply_effect(self, environment):
        """Apply the effect to the environment; specifics should be implemented in subclasses."""
        pass

# %%
class Disease:
    def __init__(self, severity=0, duration=0, frequency=1):
        self.severity = severity
        self.duration = duration
        self.active = False

    def activate(self):
        if self.severity > 0 and self.duration > 0:
            self.active = True
            # print(f"Disease activated with severity {self.severity} and duration {self.duration}")
        else:
            # print("Disease parameters set to zero, not activating disease.")
            pass

    def deactivate(self):
        self.active = False

    def update(self, environment):
        """Update the disease status and apply effects to the environment."""
        if not self.active or self.duration <= 0:
            return  # Skip updating if the disease is not active or the duration has expired

        # Apply effects such as spreading the disease to agents
        for agent in environment.agents:
            if agent.is_infected:
                neighbors = environment.get_von_neumann_neighbors(agent.location)
                agent.check_and_infect_neighbors(neighbors, self.severity)

        # Decrement the duration only if the disease is active
        self.duration -= 1

    def is_over(self):
        """Check if the disease's active period has ended."""
        return self.duration <= 0

# %%
class DataCollection:
    def __init__(self):
        self.simulation_data = []

    def process_agent_history(self, agent_history, config_id, simulation_id, replacements, deaths_due_to_age, deaths_due_to_starvation):
        # Flatten the agent_history list and add simulation metadata
        flattened_data = [
            (config_id, simulation_id, step, *agent, replacements, deaths_due_to_age, deaths_due_to_starvation)
            for step, agents in enumerate(agent_history)
            for agent in agents
        ]
        # Append to the data list
        self.simulation_data.extend(flattened_data)

    def get_simulation_data(self):
        # Create a DataFrame with the collected data
        columns = [
            'config_id', 'simulation_id', 'step', 'location', 'type', 'sugar', 'metabolism', 'vision', 'age', 'is_infected', 'alive', 
            'replacements', 'deaths_due_to_age', 'deaths_due_to_starvation'
        ]
        return pd.DataFrame(self.simulation_data, columns=columns)

    def calculate_population_data(self):
        df = self.get_simulation_data()
        population_data = []

        for config_id in df['config_id'].unique():
            config_data = df[df['config_id'] == config_id]
            for simulation_id in config_data['simulation_id'].unique():
                simulation_data = config_data[config_data['simulation_id'] == simulation_id]
                for step in simulation_data['step'].unique():
                    step_data = simulation_data[simulation_data['step'] == step]
                    total_population = len(step_data)
                    altruistic_count = len(step_data[step_data['type'] == 'altruistic'])
                    selfish_count = len(step_data[step_data['type'] == 'selfish'])
                    population_data.append((config_id, simulation_id, step, total_population, altruistic_count, selfish_count))

        population_df = pd.DataFrame(population_data, columns=['config_id', 'simulation_id', 'step', 'total_population', 'altruistic_count', 'selfish_count'])
        return population_df

# %%
class Visualization:
    def __init__(self, environment, max_capacity=6):
        self.environment = environment
        self.max_capacity = max_capacity
        self.fig, self.ax = plt.subplots()
        self.colors = {'selfish': 'red', 'altruistic': 'blue'}
        
        # Dynamically create colormap and bounds based on max_capacity
        self.cmap = self.create_colormap(self.max_capacity)
        self.bounds = list(range(self.max_capacity + 1))
        self.norm = mcolors.BoundaryNorm(self.bounds, self.cmap.N)

    def create_colormap(self, max_capacity):
        base_colors = ['#c2b280', '#ccffcc', '#99ff99', '#66cc66', '#339933', '#004d00', '#f0e68c']
        return mcolors.ListedColormap(base_colors[:max_capacity + 1])

    def visualize_state(self, step=None):
        """Visualizes the state of the grid with agents at a given timestep."""
        self.ax.clear()
        grid_state = self.environment.grid if step is None else self.environment.history[step]
        self.ax.imshow(grid_state, cmap=self.cmap, norm=self.norm, interpolation='nearest')

        # Annotate each cell with its sugar level
        for (j, i), label in np.ndenumerate(grid_state):
            self.ax.text(i, j, label, ha='center', va='center', color='black')

        # Overlay agents as colored dots based on their type
        if step is None:
            agents = self.environment.agents
        else:
            agents = self.environment.agents_history[step]
        
        for agent in agents:
            location, agent_type, sugar, metabolism, vision, age, is_infected = agent
            color = self.colors[agent_type]
            self.ax.plot(location[1], location[0], 'o', color=color, markersize=5)
        
        self.ax.set_title('Grid State at Step {}'.format(step))
        self.ax.set_xticks([])
        self.ax.set_yticks([])
        plt.show()

    def animate_simulation(self, interval=200):
        def update(frame):
            self.ax.clear()
            grid_state = self.environment.history[frame]
            self.ax.imshow(grid_state, cmap=self.cmap, norm=self.norm, interpolation='nearest')
            
            agents_state = self.environment.agents_history[frame]
            for agent in agents_state:
                (agent_location, agent_type, sugar, metabolism, vision, age, is_infected, alive) = agent
                agent_color = self.colors[agent_type] if alive else 'gray'
                self.ax.plot(agent_location[1], agent_location[0], 'o', color=agent_color, markersize=5, alpha=1 if alive else 0.5)
            
            self.ax.set_xticks([])
            self.ax.set_yticks([])
            self.ax.set_title(f'Step {frame}')

        frames = len(self.environment.history)
        anim = FuncAnimation(self.fig, update, frames=frames, interval=interval, repeat=False)
        plt.close(self.fig)
        return anim

# %%
class Experiment:
    def __init__(self, num_agents, size, max_capacity, num_simulations, steps_per_simulation, 
                 agent_vision_range, agent_metabolism_range, configurations, 
                 agent_lifespan_range=(60, 100), enable_seasons=True, tau=0.5, d=0.1):
        self.num_agents = num_agents
        self.size = size
        self.max_capacity = max_capacity
        self.num_simulations = num_simulations
        self.steps_per_simulation = steps_per_simulation
        self.agent_vision_range = agent_vision_range
        self.agent_metabolism_range = agent_metabolism_range
        self.agent_lifespan_range = agent_lifespan_range
        self.enable_seasons = enable_seasons
        self.configurations = configurations
        self.tau = tau
        self.d = d
        self.data_collection = DataCollection()
        self.baseline_run = False

    def run_simulation(self, config_id, simulation_id):
        eco_part, disease_part = config_id.split('_')
        eco_severity, eco_duration, eco_frequency = map(int, eco_part.replace('Eco-', '').split('-'))
        disease_severity, disease_duration, disease_frequency = map(float, disease_part.replace('Disease-', '').split('-'))

        environment = Environment(
            self.size,
            self.max_capacity,
            self.agent_vision_range,
            self.agent_metabolism_range,
            self.enable_seasons,
            self.tau,
            self.d
        )

        crisis_steps = sorted(random.sample(range(self.steps_per_simulation), eco_frequency)) if eco_frequency > 0 else []
        disease_steps = sorted(random.sample(range(self.steps_per_simulation), int(disease_frequency))) if disease_frequency > 0 else []

        for _ in range(self.num_agents):
            location = environment.generate_random_unoccupied_location()
            vision = np.random.randint(self.agent_vision_range[0], self.agent_vision_range[1] + 1)
            metabolism = np.random.randint(self.agent_metabolism_range[0], self.agent_metabolism_range[1] + 1)
            sugar = np.random.randint(5, 26)
            max_age = np.random.randint(self.agent_lifespan_range[0], self.agent_lifespan_range[1] + 1)
            agent = Agent(location=location, sugar=sugar, metabolism=metabolism, vision=vision, max_age=max_age)
            environment.add_agent(agent)

        environment.capture_agents_initial_data()

        for step in range(self.steps_per_simulation):
            if step in crisis_steps:
                crisis = EcoCrisis(eco_severity, eco_duration)
                environment.trigger_crisis(crisis)
            if step in disease_steps:
                disease = Disease(disease_severity, disease_duration)
                environment.trigger_disease(disease)
            environment.step()

        self.data_collection.process_agent_history(
            environment.agents_history,
            config_id,
            simulation_id,
            environment.replacements,
            environment.deaths_due_to_age,
            environment.deaths_due_to_starvation
        )

    def run_experiment(self):
        futures = []
        for config_id in self.configurations:
            print(f"Running experiment with Configuration ID: {config_id}")

            eco_config, disease_config = config_id.split('_')
            eco_severity, eco_duration, eco_frequency = map(int, eco_config.replace('Eco-', '').split('-'))
            disease_severity, disease_duration, disease_frequency = map(float, disease_config.replace('Disease-', '').split('-'))

            is_baseline = (eco_severity == 0 and eco_duration == 0 and eco_frequency == 0 and
                           disease_severity == 0 and disease_duration == 0 and disease_frequency == 0)

            if is_baseline:
                if not self.baseline_run:
                    self.baseline_run = True
                for simulation in range(self.num_simulations):
                    self.run_simulation(config_id, simulation + 1)
                continue

            if ((eco_severity == 0 or eco_duration == 0 or eco_frequency == 0) and 
                (disease_severity == 0 or disease_duration == 0 or disease_frequency == 0)):
                continue

            for simulation in range(self.num_simulations):
                self.run_simulation(config_id, simulation + 1)

        population_data = self.data_collection.calculate_population_data()

        for config_id in self.configurations:
            print(f"\nPopulation data for Configuration ID: {config_id}")
            config_population_data = population_data[population_data['config_id'] == config_id]

            for simulation_id in config_population_data['simulation_id'].unique():
                print(f"\nSimulation {simulation_id}:")
                simulation_data = config_population_data[config_population_data['simulation_id'] == simulation_id]

                for step in sorted(simulation_data['step'].unique()):
                    step_data = simulation_data[simulation_data['step'] == step]
                    total_population = step_data['total_population'].values[0]
                    altruistic_count = step_data['altruistic_count'].values[0]
                    selfish_count = step_data['selfish_count'].values[0]
                    print(f"Step {step}: Total = {total_population}, Altruistic = {altruistic_count}, Selfish = {selfish_count}")

        return population_data

# %%
# Set random seed for reproducibility
np.random.seed(42)

# Experiment parameters
num_agents = 400
environment_size = (50, 50)
max_capacity = 6
num_simulations = 5
steps_per_simulation = 250
enable_seasons = False
vision_range = (1, 6)
metabolism_range = (1, 4)
agent_lifespan_range = (60, 100)
tau = 0.2
d = 0

configurations = {
    'Eco-0-0-0_Disease-0-0-0': {'eco': (0, 0, 0), 'disease': (0, 0, 0)},
    'Eco-4-25-5_Disease-1-15-9': {'eco': (4, 25, 5), 'disease': (1, 15, 9)},
    'Eco-8-25-5_Disease-1-15-9': {'eco': (8, 25, 5), 'disease': (1, 15, 9)}
}

# Create an instance of the Experiment class using Ray's remote method
experiment = Experiment(num_agents=num_agents, size=environment_size, max_capacity=max_capacity,
                               num_simulations=num_simulations, steps_per_simulation=steps_per_simulation,
                               agent_vision_range=vision_range, agent_metabolism_range=metabolism_range,
                               agent_lifespan_range=agent_lifespan_range, enable_seasons=enable_seasons,
                               configurations=configurations, tau=tau, d=d)

# Timing the experiment
start_time = time.time()

# Run the experiment in parallel
experiment.run_experiment()

# Calculate the total experiment time
end_time = time.time()
duration_seconds = end_time - start_time
duration_minutes = duration_seconds / 60

# Output the duration of the experiment
print(f"The experiment took {duration_minutes:.2f} minutes to complete.")
# Out:
# Running experiment with Configuration ID: Eco-0-0-0_Disease-0-0-0
# Running experiment with Configuration ID: Eco-4-25-5_Disease-1-15-9
# Running experiment with Configuration ID: Eco-8-25-5_Disease-1-15-9
#
# Population data for Configuration ID: Eco-0-0-0_Disease-0-0-0
#
# Simulation 1:
# Step 0: Total = 400, Altruistic = 198, Selfish = 202
# Step 1: Total = 399, Altruistic = 197, Selfish = 202
# Step 2: Total = 399, Altruistic = 197, Selfish = 202
# Step 3: Total = 396, Altruistic = 196, Selfish = 200
# Step 4: Total = 393, Altruistic = 194, Selfish = 199
# Step 5: Total = 388, Altruistic = 190, Selfish = 198
# Step 6: Total = 386, Altruistic = 190, Selfish = 196
# Step 7: Total = 384, Altruistic = 189, Selfish = 195
# Step 8: Total = 380, Altruistic = 187, Selfish = 193
# Step 9: Total = 379, Altruistic = 186, Selfish = 193
# Step 10: Total = 377, Altruistic = 185, Selfish = 192
# Step 11: Total = 375, Altruistic = 184, Selfish = 191
# Step 12: Total = 416, Altruistic = 184, Selfish = 232
# Step 116: Total = 1552, Altruistic = 0, Selfish = 1552
# Step 117: Total = 1560, Altruistic = 0, Selfish = 1560
# Step 118: Total = 1566, Altruistic = 0, Selfish = 1566
# Step 119: Total = 1563, Altruistic = 0, Selfish = 1563
# Step 120: Total = 1563, Altruistic = 0, Selfish = 1563
# Step 121: Total = 1571, Altruistic = 0, Selfish = 1571
# Step 122: Total = 1572, Altruistic = 0, Selfish = 1572
# Step 123: Total = 1584, Altruistic = 0, Selfish = 1584
# Step 124: Total = 1584, Altruistic = 0, Selfish = 1584
# Step 125: Total = 1592, Altruistic = 0, Selfish = 1592
# Step 126: Total = 1593, Altruistic = 0, Selfish = 1593
# Step 127: Total = 1598, Altruistic = 0, Selfish = 1598
# Step 128: Total = 1601, Altruistic = 0, Selfish = 1601
# Step 129: Total = 1625, Altruistic = 0, Selfish = 1625
# Step 130: Total = 1630, Altruistic = 0, Selfish = 1630
# Step 131: Total = 1645, Altruistic = 0, Selfish = 1645
# Step 132: Total = 1649, Altruistic = 0, Selfish = 1649
# Step 133: Total = 1645, Altruistic = 0, Selfish = 1645
# Step 134: Total = 1648, Altruistic = 0, Selfish = 1648
# Step 135: Total = 1656, Altruistic = 0, Selfish = 1656
# Step 136: Total = 1653, Altruistic = 0, Selfish = 1653
# Step 137: Total = 1661, Altruistic = 0, Selfish = 1661
# Step 138: Total = 1668, Altruistic = 0, Selfish = 1668
# Step 139: Total = 1671, Altruistic = 0, Selfish = 1671
# Step 140: Total = 1664, Altruistic = 0, Selfish = 1664
# Step 141: Total = 1673, Altruistic = 0, Selfish = 1673
# Step 142: Total = 1675, Altruistic = 0, Selfish = 1675
# Step 143: Total = 1669, Altruistic = 0, Selfish = 1669
# Step 144: Total = 1675, Altruistic = 0, Selfish = 1675
# Step 145: Total = 1688, Altruistic = 0, Selfish = 1688
# Step 146: Total = 1684, Altruistic = 0, Selfish = 1684
# Step 147: Total = 1693, Altruistic = 0, Selfish = 1693
# Step 148: Total = 1700, Altruistic = 0, Selfish = 1700
# Step 149: Total = 1710, Altruistic = 0, Selfish = 1710
# Step 150: Total = 1711, Altruistic = 0, Selfish = 1711
# Step 151: Total = 1707, Altruistic = 0, Selfish = 1707
# Step 152: Total = 1716, Altruistic = 0, Selfish = 1716
# Step 153: Total = 1715, Altruistic = 0, Selfish = 1715
# Step 154: Total = 1714, Altruistic = 0, Selfish = 1714
# Step 155: Total = 1716, Altruistic = 0, Selfish = 1716
# Step 156: Total = 1717, Altruistic = 0, Selfish = 1717
# Step 157: Total = 1707, Altruistic = 0, Selfish = 1707
# Step 158: Total = 1714, Altruistic = 0, Selfish = 1714
# Step 159: Total = 1726, Altruistic = 0, Selfish = 1726
# Step 160: Total = 1725, Altruistic = 0, Selfish = 1725
# Step 161: Total = 1720, Altruistic = 0, Selfish = 1720
# Step 162: Total = 1730, Altruistic = 0, Selfish = 1730
# Step 163: Total = 1743, Altruistic = 0, Selfish = 1743
# Step 164: Total = 1738, Altruistic = 0, Selfish = 1738
# Step 165: Total = 1744, Altruistic = 0, Selfish = 1744
# Step 166: Total = 1749, Altruistic = 0, Selfish = 1749
# Step 167: Total = 1761, Altruistic = 0, Selfish = 1761
# Step 168: Total = 1754, Altruistic = 0, Selfish = 1754
# Step 169: Total = 1763, Altruistic = 0, Selfish = 1763
# Step 170: Total = 1756, Altruistic = 0, Selfish = 1756
# Step 171: Total = 1762, Altruistic = 0, Selfish = 1762
# Step 172: Total = 1766, Altruistic = 0, Selfish = 1766
# Step 173: Total = 1765, Altruistic = 0, Selfish = 1765
# Step 174: Total = 1770, Altruistic = 0, Selfish = 1770
# Step 175: Total = 1773, Altruistic = 0, Selfish = 1773
# Step 176: Total = 1787, Altruistic = 0, Selfish = 1787
# Step 177: Total = 1773, Altruistic = 0, Selfish = 1773
# Step 178: Total = 1778, Altruistic = 0, Selfish = 1778
# Step 179: Total = 1776, Altruistic = 0, Selfish = 1776
# Step 180: Total = 1773, Altruistic = 0, Selfish = 1773
# Step 181: Total = 1776, Altruistic = 0, Selfish = 1776
# Step 182: Total = 1784, Altruistic = 0, Selfish = 1784
# Step 183: Total = 1793, Altruistic = 0, Selfish = 1793
# Step 184: Total = 1792, Altruistic = 0, Selfish = 1792
# Step 185: Total = 1800, Altruistic = 0, Selfish = 1800
# Step 186: Total = 1796, Altruistic = 0, Selfish = 1796
# Step 187: Total = 1802, Altruistic = 0, Selfish = 1802
# Step 188: Total = 1796, Altruistic = 0, Selfish = 1796
# Step 189: Total = 1791, Altruistic = 0, Selfish = 1791
# Step 190: Total = 1787, Altruistic = 0, Selfish = 1787
# Step 191: Total = 1784, Altruistic = 0, Selfish = 1784
# Step 192: Total = 1797, Altruistic = 0, Selfish = 1797
# Step 193: Total = 1784, Altruistic = 0, Selfish = 1784
# Step 194: Total = 1792, Altruistic = 0, Selfish = 1792
# Step 195: Total = 1806, Altruistic = 0, Selfish = 1806
# Step 196: Total = 1802, Altruistic = 0, Selfish = 1802
# Step 197: Total = 1800, Altruistic = 0, Selfish = 1800
# Step 198: Total = 1813, Altruistic = 0, Selfish = 1813
# Step 199: Total = 1804, Altruistic = 0, Selfish = 1804
# Step 200: Total = 1791, Altruistic = 0, Selfish = 1791
# Step 201: Total = 1810, Altruistic = 0, Selfish = 1810
# Step 202: Total = 1806, Altruistic = 0, Selfish = 1806
# Step 203: Total = 1808, Altruistic = 0, Selfish = 1808
# Step 204: Total = 1801, Altruistic = 0, Selfish = 1801
# Step 205: Total = 1800, Altruistic = 0, Selfish = 1800
# Step 206: Total = 1806, Altruistic = 0, Selfish = 1806
# Step 207: Total = 1805, Altruistic = 0, Selfish = 1805
# Step 208: Total = 1814, Altruistic = 0, Selfish = 1814
# Step 209: Total = 1809, Altruistic = 0, Selfish = 1809
# Step 210: Total = 1806, Altruistic = 0, Selfish = 1806
# Step 211: Total = 1806, Altruistic = 0, Selfish = 1806
# Step 212: Total = 1793, Altruistic = 0, Selfish = 1793
# Step 213: Total = 1783, Altruistic = 0, Selfish = 1783
# Step 214: Total = 1785, Altruistic = 0, Selfish = 1785
# Step 215: Total = 1783, Altruistic = 0, Selfish = 1783
# Step 69: Total = 1395, Altruistic = 151, Selfish = 1244
# Step 70: Total = 1418, Altruistic = 143, Selfish = 1275
# Step 71: Total = 1422, Altruistic = 138, Selfish = 1284
# Step 72: Total = 1434, Altruistic = 135, Selfish = 1299
# Step 73: Total = 1435, Altruistic = 130, Selfish = 1305
# Step 74: Total = 1449, Altruistic = 126, Selfish = 1323
# Step 75: Total = 1458, Altruistic = 121, Selfish = 1337
# Step 76: Total = 1470, Altruistic = 119, Selfish = 1351
# Step 77: Total = 1481, Altruistic = 114, Selfish = 1367
# Step 78: Total = 1486, Altruistic = 107, Selfish = 1379
# Step 79: Total = 1502, Altruistic = 102, Selfish = 1400
# Step 80: Total = 1511, Altruistic = 96, Selfish = 1415
# Step 81: Total = 1510, Altruistic = 87, Selfish = 1423
# Step 82: Total = 1514, Altruistic = 83, Selfish = 1431
# Step 83: Total = 1523, Altruistic = 79, Selfish = 1444
# Step 84: Total = 1532, Altruistic = 75, Selfish = 1457
# Step 85: Total = 1547, Altruistic = 70, Selfish = 1477
# Step 86: Total = 1547, Altruistic = 67, Selfish = 1480
# Step 87: Total = 1549, Altruistic = 61, Selfish = 1488
# Step 88: Total = 1558, Altruistic = 57, Selfish = 1501
# Step 89: Total = 1562, Altruistic = 52, Selfish = 1510
# Step 90: Total = 1562, Altruistic = 46, Selfish = 1516
# Step 91: Total = 1561, Altruistic = 41, Selfish = 1520
# Step 92: Total = 1575, Altruistic = 38, Selfish = 1537
# Step 93: Total = 1580, Altruistic = 35, Selfish = 1545
# Step 94: Total = 1583, Altruistic = 29, Selfish = 1554
# Step 95: Total = 1575, Altruistic = 24, Selfish = 1551
# Step 96: Total = 1575, Altruistic = 21, Selfish = 1554
# Step 97: Total = 1574, Altruistic = 17, Selfish = 1557
# Step 98: Total = 1567, Altruistic = 13, Selfish = 1554
# Step 99: Total = 1583, Altruistic = 11, Selfish = 1572
# Step 100: Total = 1580, Altruistic = 3, Selfish = 1577
# Step 101: Total = 1570, Altruistic = 0, Selfish = 1570
# Step 102: Total = 1586, Altruistic = 0, Selfish = 1586
# Step 103: Total = 1596, Altruistic = 0, Selfish = 1596
# Step 104: Total = 1604, Altruistic = 0, Selfish = 1604
# Step 105: Total = 1606, Altruistic = 0, Selfish = 1606
# Step 106: Total = 1614, Altruistic = 0, Selfish = 1614
# Step 107: Total = 1629, Altruistic = 0, Selfish = 1629
# Step 108: Total = 1636, Altruistic = 0, Selfish = 1636
# Step 109: Total = 1636, Altruistic = 0, Selfish = 1636
# Step 110: Total = 1642, Altruistic = 0, Selfish = 1642
# Step 111: Total = 1657, Altruistic = 0, Selfish = 1657
# Step 112: Total = 1665, Altruistic = 0, Selfish = 1665
# Step 113: Total = 1662, Altruistic = 0, Selfish = 1662
# Step 114: Total = 1664, Altruistic = 0, Selfish = 1664
# Step 115: Total = 1672, Altruistic = 0, Selfish = 1672
# Step 116: Total = 1678, Altruistic = 0, Selfish = 1678
# Step 117: Total = 1678, Altruistic = 0, Selfish = 1678
# Step 118: Total = 1680, Altruistic = 0, Selfish = 1680
# Step 220: Total = 1769, Altruistic = 0, Selfish = 1769
# Step 221: Total = 1780, Altruistic = 0, Selfish = 1780
# Step 222: Total = 1788, Altruistic = 0, Selfish = 1788
# Step 223: Total = 1789, Altruistic = 0, Selfish = 1789
# Step 224: Total = 1781, Altruistic = 0, Selfish = 1781
# Step 225: Total = 1790, Altruistic = 0, Selfish = 1790
# Step 226: Total = 1782, Altruistic = 0, Selfish = 1782
# Step 227: Total = 1784, Altruistic = 0, Selfish = 1784
# Step 228: Total = 1789, Altruistic = 0, Selfish = 1789
# Step 229: Total = 1784, Altruistic = 0, Selfish = 1784
# Step 230: Total = 1792, Altruistic = 0, Selfish = 1792
# Step 231: Total = 1795, Altruistic = 0, Selfish = 1795
# Step 232: Total = 1800, Altruistic = 0, Selfish = 1800
# Step 233: Total = 1802, Altruistic = 0, Selfish = 1802
# Step 234: Total = 1811, Altruistic = 0, Selfish = 1811
# Step 235: Total = 1819, Altruistic = 0, Selfish = 1819
# Step 236: Total = 1817, Altruistic = 0, Selfish = 1817
# Step 237: Total = 1817, Altruistic = 0, Selfish = 1817
# Step 238: Total = 1823, Altruistic = 0, Selfish = 1823
# Step 239: Total = 1834, Altruistic = 0, Selfish = 1834
# Step 240: Total = 1842, Altruistic = 0, Selfish = 1842
# Step 241: Total = 1841, Altruistic = 0, Selfish = 1841
# Step 242: Total = 1844, Altruistic = 0, Selfish = 1844
# Step 243: Total = 1843, Altruistic = 0, Selfish = 1843
# Step 244: Total = 1840, Altruistic = 0, Selfish = 1840
# Step 245: Total = 1824, Altruistic = 0, Selfish = 1824
# Step 246: Total = 1830, Altruistic = 0, Selfish = 1830
# Step 247: Total = 1834, Altruistic = 0, Selfish = 1834
# Step 248: Total = 1847, Altruistic = 0, Selfish = 1847
# Step 249: Total = 1843, Altruistic = 0, Selfish = 1843
# Step 250: Total = 1848, Altruistic = 0, Selfish = 1848
#
# Simulation 3:
# Step 0: Total = 400, Altruistic = 182, Selfish = 218
# Step 1: Total = 400, Altruistic = 182, Selfish = 218
# Step 2: Total = 399, Altruistic = 181, Selfish = 218
# Step 3: Total = 396, Altruistic = 179, Selfish = 217
# Step 4: Total = 394, Altruistic = 178, Selfish = 216
# Step 5: Total = 390, Altruistic = 174, Selfish = 216
# Step 6: Total = 388, Altruistic = 173, Selfish = 215
# Step 7: Total = 385, Altruistic = 170, Selfish = 215
# Step 8: Total = 385, Altruistic = 170, Selfish = 215
# Step 9: Total = 382, Altruistic = 170, Selfish = 212
# Step 10: Total = 380, Altruistic = 169, Selfish = 211
# Step 11: Total = 380, Altruistic = 169, Selfish = 211
# Step 12: Total = 418, Altruistic = 169, Selfish = 249
# Step 13: Total = 431, Altruistic = 168, Selfish = 263
# Step 14: Total = 442, Altruistic = 168, Selfish = 274
# Step 15: Total = 453, Altruistic = 168, Selfish = 285
# Step 16: Total = 465, Altruistic = 167, Selfish = 298
# Step 17: Total = 482, Altruistic = 167, Selfish = 315
# Step 18: Total = 494, Altruistic = 167, Selfish = 327
# Step 19: Total = 511, Altruistic = 167, Selfish = 344
# Step 72: Total = 1373, Altruistic = 119, Selfish = 1254
# Step 73: Total = 1387, Altruistic = 117, Selfish = 1270
# Step 74: Total = 1394, Altruistic = 110, Selfish = 1284
# Step 75: Total = 1402, Altruistic = 106, Selfish = 1296
# Step 76: Total = 1406, Altruistic = 101, Selfish = 1305
# Step 77: Total = 1415, Altruistic = 94, Selfish = 1321
# Step 78: Total = 1418, Altruistic = 88, Selfish = 1330
# Step 79: Total = 1429, Altruistic = 84, Selfish = 1345
# Step 80: Total = 1437, Altruistic = 78, Selfish = 1359
# Step 81: Total = 1442, Altruistic = 74, Selfish = 1368
# Step 82: Total = 1439, Altruistic = 71, Selfish = 1368
# Step 83: Total = 1443, Altruistic = 67, Selfish = 1376
# Step 84: Total = 1449, Altruistic = 66, Selfish = 1383
# Step 85: Total = 1458, Altruistic = 63, Selfish = 1395
# Step 86: Total = 1462, Altruistic = 56, Selfish = 1406
# Step 87: Total = 1470, Altruistic = 52, Selfish = 1418
# Step 88: Total = 1483, Altruistic = 48, Selfish = 1435
# Step 89: Total = 1478, Altruistic = 42, Selfish = 1436
# Step 90: Total = 1481, Altruistic = 41, Selfish = 1440
# Step 91: Total = 1494, Altruistic = 38, Selfish = 1456
# Step 92: Total = 1496, Altruistic = 34, Selfish = 1462
# Step 93: Total = 1508, Altruistic = 32, Selfish = 1476
# Step 94: Total = 1507, Altruistic = 29, Selfish = 1478
# Step 95: Total = 1510, Altruistic = 25, Selfish = 1485
# Step 96: Total = 1505, Altruistic = 19, Selfish = 1486
# Step 97: Total = 1506, Altruistic = 14, Selfish = 1492
# Step 98: Total = 1509, Altruistic = 11, Selfish = 1498
# Step 99: Total = 1519, Altruistic = 7, Selfish = 1512
# Step 100: Total = 1519, Altruistic = 4, Selfish = 1515
# Step 101: Total = 1520, Altruistic = 0, Selfish = 1520
# Step 102: Total = 1535, Altruistic = 0, Selfish = 1535
# Step 103: Total = 1540, Altruistic = 0, Selfish = 1540
# Step 104: Total = 1535, Altruistic = 0, Selfish = 1535
# Step 105: Total = 1549, Altruistic = 0, Selfish = 1549
# Step 106: Total = 1552, Altruistic = 0, Selfish = 1552
# Step 107: Total = 1556, Altruistic = 0, Selfish = 1556
# Step 108: Total = 1554, Altruistic = 0, Selfish = 1554
# Step 109: Total = 1559, Altruistic = 0, Selfish = 1559
# Step 110: Total = 1574, Altruistic = 0, Selfish = 1574
# Step 111: Total = 1581, Altruistic = 0, Selfish = 1581
# Step 112: Total = 1583, Altruistic = 0, Selfish = 1583
# Step 113: Total = 1590, Altruistic = 0, Selfish = 1590
# Step 114: Total = 1594, Altruistic = 0, Selfish = 1594
# Step 115: Total = 1582, Altruistic = 0, Selfish = 1582
# Step 116: Total = 1583, Altruistic = 0, Selfish = 1583
# Step 117: Total = 1587, Altruistic = 0, Selfish = 1587
# Step 118: Total = 1586, Altruistic = 0, Selfish = 1586
# Step 119: Total = 1588, Altruistic = 0, Selfish = 1588
# Step 120: Total = 1598, Altruistic = 0, Selfish = 1598
# Step 121: Total = 1600, Altruistic = 0, Selfish = 1600
# Step 122: Total = 1588, Altruistic = 0, Selfish = 1588
# Step 123: Total = 1599, Altruistic = 0, Selfish = 1599
# Step 124: Total = 1603, Altruistic = 0, Selfish = 1603
# Step 125: Total = 1619, Altruistic = 0, Selfish = 1619
# Step 126: Total = 1623, Altruistic = 0, Selfish = 1623
# Step 127: Total = 1628, Altruistic = 0, Selfish = 1628
# Step 128: Total = 1633, Altruistic = 0, Selfish = 1633
# Step 129: Total = 1630, Altruistic = 0, Selfish = 1630
# Step 130: Total = 1636, Altruistic = 0, Selfish = 1636
# Step 131: Total = 1639, Altruistic = 0, Selfish = 1639
# Step 132: Total = 1635, Altruistic = 0, Selfish = 1635
# Step 133: Total = 1631, Altruistic = 0, Selfish = 1631
# Step 134: Total = 1623, Altruistic = 0, Selfish = 1623
# Step 135: Total = 1626, Altruistic = 0, Selfish = 1626
# Step 136: Total = 1613, Altruistic = 0, Selfish = 1613
# Step 137: Total = 1618, Altruistic = 0, Selfish = 1618
# Step 138: Total = 1612, Altruistic = 0, Selfish = 1612
# Step 139: Total = 1619, Altruistic = 0, Selfish = 1619
# Step 140: Total = 1626, Altruistic = 0, Selfish = 1626
# Step 141: Total = 1634, Altruistic = 0, Selfish = 1634
# Step 142: Total = 1627, Altruistic = 0, Selfish = 1627
# Step 143: Total = 1631, Altruistic = 0, Selfish = 1631
# Step 144: Total = 1624, Altruistic = 0, Selfish = 1624
# Step 145: Total = 1617, Altruistic = 0, Selfish = 1617
# Step 146: Total = 1621, Altruistic = 0, Selfish = 1621
# Step 147: Total = 1630, Altruistic = 0, Selfish = 1630
# Step 148: Total = 1634, Altruistic = 0, Selfish = 1634
# Step 149: Total = 1644, Altruistic = 0, Selfish = 1644
# Step 150: Total = 1640, Altruistic = 0, Selfish = 1640
# Step 151: Total = 1633, Altruistic = 0, Selfish = 1633
# Step 152: Total = 1641, Altruistic = 0, Selfish = 1641
# Step 153: Total = 1646, Altruistic = 0, Selfish = 1646
# Step 154: Total = 1642, Altruistic = 0, Selfish = 1642
# Step 155: Total = 1642, Altruistic = 0, Selfish = 1642
# Step 156: Total = 1636, Altruistic = 0, Selfish = 1636
# Step 157: Total = 1639, Altruistic = 0, Selfish = 1639
# Step 158: Total = 1628, Altruistic = 0, Selfish = 1628
# Step 159: Total = 1641, Altruistic = 0, Selfish = 1641
# Step 160: Total = 1657, Altruistic = 0, Selfish = 1657
# Step 161: Total = 1662, Altruistic = 0, Selfish = 1662
# Step 162: Total = 1664, Altruistic = 0, Selfish = 1664
# Step 163: Total = 1669, Altruistic = 0, Selfish = 1669
# Step 164: Total = 1673, Altruistic = 0, Selfish = 1673
# Step 165: Total = 1671, Altruistic = 0, Selfish = 1671
# Step 166: Total = 1677, Altruistic = 0, Selfish = 1677
# Step 167: Total = 1681, Altruistic = 0, Selfish = 1681
# Step 168: Total = 1683, Altruistic = 0, Selfish = 1683
# Step 169: Total = 1674, Altruistic = 0, Selfish = 1674
# Step 170: Total = 1679, Altruistic = 0, Selfish = 1679
# Step 171: Total = 1679, Altruistic = 0, Selfish = 1679
# Step 223: Total = 1782, Altruistic = 0, Selfish = 1782
# Step 224: Total = 1774, Altruistic = 0, Selfish = 1774
# Step 225: Total = 1773, Altruistic = 0, Selfish = 1773
# Step 226: Total = 1779, Altruistic = 0, Selfish = 1779
# Step 227: Total = 1784, Altruistic = 0, Selfish = 1784
# Step 228: Total = 1793, Altruistic = 0, Selfish = 1793
# Step 229: Total = 1795, Altruistic = 0, Selfish = 1795
# Step 230: Total = 1794, Altruistic = 0, Selfish = 1794
# Step 231: Total = 1801, Altruistic = 0, Selfish = 1801
# Step 232: Total = 1798, Altruistic = 0, Selfish = 1798
# Step 233: Total = 1794, Altruistic = 0, Selfish = 1794
# Step 234: Total = 1794, Altruistic = 0, Selfish = 1794
# Step 235: Total = 1793, Altruistic = 0, Selfish = 1793
# Step 236: Total = 1785, Altruistic = 0, Selfish = 1785
# Step 237: Total = 1778, Altruistic = 0, Selfish = 1778
# Step 238: Total = 1781, Altruistic = 0, Selfish = 1781
# Step 239: Total = 1785, Altruistic = 0, Selfish = 1785
# Step 240: Total = 1795, Altruistic = 0, Selfish = 1795
# Step 241: Total = 1791, Altruistic = 0, Selfish = 1791
# Step 242: Total = 1798, Altruistic = 0, Selfish = 1798
# Step 243: Total = 1792, Altruistic = 0, Selfish = 1792
# Step 244: Total = 1792, Altruistic = 0, Selfish = 1792
# Step 245: Total = 1795, Altruistic = 0, Selfish = 1795
# Step 246: Total = 1804, Altruistic = 0, Selfish = 1804
# Step 247: Total = 1794, Altruistic = 0, Selfish = 1794
# Step 248: Total = 1811, Altruistic = 0, Selfish = 1811
# Step 249: Total = 1810, Altruistic = 0, Selfish = 1810
# Step 250: Total = 1801, Altruistic = 0, Selfish = 1801
#
# Simulation 4:
# Step 0: Total = 400, Altruistic = 205, Selfish = 195
# Step 1: Total = 400, Altruistic = 205, Selfish = 195
# Step 2: Total = 396, Altruistic = 202, Selfish = 194
# Step 3: Total = 392, Altruistic = 199, Selfish = 193
# Step 4: Total = 389, Altruistic = 196, Selfish = 193
# Step 5: Total = 387, Altruistic = 195, Selfish = 192
# Step 6: Total = 384, Altruistic = 193, Selfish = 191
# Step 7: Total = 384, Altruistic = 193, Selfish = 191
# Step 8: Total = 382, Altruistic = 193, Selfish = 189
# Step 9: Total = 382, Altruistic = 193, Selfish = 189
# Step 10: Total = 382, Altruistic = 193, Selfish = 189
# Step 11: Total = 382, Altruistic = 193, Selfish = 189
# Step 12: Total = 431, Altruistic = 193, Selfish = 238
# Step 13: Total = 440, Altruistic = 193, Selfish = 247
# Step 14: Total = 450, Altruistic = 193, Selfish = 257
# Step 15: Total = 461, Altruistic = 193, Selfish = 268
# Step 16: Total = 472, Altruistic = 193, Selfish = 279
# Step 17: Total = 485, Altruistic = 193, Selfish = 292
# Step 18: Total = 499, Altruistic = 193, Selfish = 306
# Step 19: Total = 517, Altruistic = 193, Selfish = 324
# Step 20: Total = 529, Altruistic = 193, Selfish = 336
# Step 21: Total = 542, Altruistic = 193, Selfish = 349
# Step 22: Total = 561, Altruistic = 193, Selfish = 368
# Step 75: Total = 1436, Altruistic = 136, Selfish = 1300
# Step 76: Total = 1451, Altruistic = 132, Selfish = 1319
# Step 77: Total = 1454, Altruistic = 125, Selfish = 1329
# Step 78: Total = 1453, Altruistic = 121, Selfish = 1332
# Step 79: Total = 1462, Altruistic = 115, Selfish = 1347
# Step 80: Total = 1476, Altruistic = 113, Selfish = 1363
# Step 81: Total = 1494, Altruistic = 110, Selfish = 1384
# Step 82: Total = 1498, Altruistic = 104, Selfish = 1394
# Step 83: Total = 1505, Altruistic = 101, Selfish = 1404
# Step 84: Total = 1504, Altruistic = 91, Selfish = 1413
# Step 85: Total = 1515, Altruistic = 87, Selfish = 1428
# Step 86: Total = 1502, Altruistic = 83, Selfish = 1419
# Step 87: Total = 1509, Altruistic = 81, Selfish = 1428
# Step 88: Total = 1517, Altruistic = 78, Selfish = 1439
# Step 89: Total = 1510, Altruistic = 68, Selfish = 1442
# Step 90: Total = 1509, Altruistic = 65, Selfish = 1444
# Step 91: Total = 1513, Altruistic = 58, Selfish = 1455
# Step 92: Total = 1513, Altruistic = 50, Selfish = 1463
# Step 93: Total = 1517, Altruistic = 43, Selfish = 1474
# Step 94: Total = 1518, Altruistic = 40, Selfish = 1478
# Step 95: Total = 1526, Altruistic = 37, Selfish = 1489
# Step 96: Total = 1533, Altruistic = 30, Selfish = 1503
# Step 97: Total = 1535, Altruistic = 25, Selfish = 1510
# Step 98: Total = 1535, Altruistic = 20, Selfish = 1515
# Step 99: Total = 1533, Altruistic = 12, Selfish = 1521
# Step 100: Total = 1537, Altruistic = 5, Selfish = 1532
# Step 101: Total = 1534, Altruistic = 0, Selfish = 1534
# Step 102: Total = 1539, Altruistic = 0, Selfish = 1539
# Step 103: Total = 1542, Altruistic = 0, Selfish = 1542
# Step 104: Total = 1543, Altruistic = 0, Selfish = 1543
# Step 105: Total = 1556, Altruistic = 0, Selfish = 1556
# Step 106: Total = 1568, Altruistic = 0, Selfish = 1568
# Step 107: Total = 1563, Altruistic = 0, Selfish = 1563
# Step 108: Total = 1564, Altruistic = 0, Selfish = 1564
# Step 109: Total = 1570, Altruistic = 0, Selfish = 1570
# Step 110: Total = 1569, Altruistic = 0, Selfish = 1569
# Step 111: Total = 1568, Altruistic = 0, Selfish = 1568
# Step 112: Total = 1571, Altruistic = 0, Selfish = 1571
# Step 113: Total = 1586, Altruistic = 0, Selfish = 1586
# Step 114: Total = 1583, Altruistic = 0, Selfish = 1583
# Step 115: Total = 1586, Altruistic = 0, Selfish = 1586
# ...
# Step 14: Total = 17, Altruistic = 1, Selfish = 16
# Step 15: Total = 10, Altruistic = 1, Selfish = 9
# Step 16: Total = 9, Altruistic = 1, Selfish = 8
# Step 17: Total = 6, Altruistic = 1, Selfish = 5
# Step 18: Total = 1, Altruistic = 1, Selfish = 0
# Step 19: Total = 1, Altruistic = 1, Selfish = 0
#
# Simulation 3:
# Step 0: Total = 400, Altruistic = 185, Selfish = 215
# Step 1: Total = 400, Altruistic = 185, Selfish = 215
# Step 2: Total = 396, Altruistic = 183, Selfish = 213
# Step 3: Total = 392, Altruistic = 179, Selfish = 213
# Step 4: Total = 367, Altruistic = 156, Selfish = 211
# Step 5: Total = 328, Altruistic = 134, Selfish = 194
# Step 6: Total = 241, Altruistic = 101, Selfish = 140
# Step 7: Total = 203, Altruistic = 83, Selfish = 120
# Step 8: Total = 181, Altruistic = 73, Selfish = 108
# Step 9: Total = 154, Altruistic = 59, Selfish = 95
# Step 10: Total = 126, Altruistic = 40, Selfish = 86
# Step 11: Total = 86, Altruistic = 20, Selfish = 66
# Step 12: Total = 61, Altruistic = 10, Selfish = 51
# Step 13: Total = 33, Altruistic = 4, Selfish = 29
# Step 14: Total = 23, Altruistic = 1, Selfish = 22
# Step 15: Total = 18, Altruistic = 1, Selfish = 17
# Step 16: Total = 12, Altruistic = 1, Selfish = 11
# Step 17: Total = 9, Altruistic = 1, Selfish = 8
# Step 18: Total = 6, Altruistic = 0, Selfish = 6
# Step 19: Total = 5, Altruistic = 0, Selfish = 5
# Step 20: Total = 3, Altruistic = 0, Selfish = 3
# Step 21: Total = 3, Altruistic = 0, Selfish = 3
# Step 22: Total = 1, Altruistic = 0, Selfish = 1
# Step 23: Total = 1, Altruistic = 0, Selfish = 1
# Step 24: Total = 1, Altruistic = 0, Selfish = 1
# Step 25: Total = 1, Altruistic = 0, Selfish = 1
# Step 26: Total = 1, Altruistic = 0, Selfish = 1
# Step 27: Total = 1, Altruistic = 0, Selfish = 1
# Step 28: Total = 1, Altruistic = 0, Selfish = 1
# Step 29: Total = 1, Altruistic = 0, Selfish = 1
#
# Simulation 4:
# Step 0: Total = 400, Altruistic = 208, Selfish = 192
# Step 1: Total = 400, Altruistic = 208, Selfish = 192
# Step 2: Total = 397, Altruistic = 207, Selfish = 190
# Step 3: Total = 395, Altruistic = 206, Selfish = 189
# Step 4: Total = 392, Altruistic = 205, Selfish = 187
# Step 5: Total = 390, Altruistic = 203, Selfish = 187
# Step 6: Total = 389, Altruistic = 203, Selfish = 186
# Step 7: Total = 389, Altruistic = 203, Selfish = 186
# Step 8: Total = 388, Altruistic = 202, Selfish = 186
# Step 9: Total = 388, Altruistic = 202, Selfish = 186
# Step 10: Total = 385, Altruistic = 199, Selfish = 186
# Step 11: Total = 375, Altruistic = 189, Selfish = 186
# Step 12: Total = 366, Altruistic = 166, Selfish = 200
# Step 13: Total = 359, Altruistic = 155, Selfish = 204
# Step 14: Total = 322, Altruistic = 137, Selfish = 185
# Step 15: Total = 290, Altruistic = 124, Selfish = 166
# Step 16: Total = 288, Altruistic = 121, Selfish = 167
# Step 17: Total = 295, Altruistic = 121, Selfish = 174
# Step 18: Total = 295, Altruistic = 121, Selfish = 174
# Step 19: Total = 301, Altruistic = 121, Selfish = 180
# Step 20: Total = 308, Altruistic = 121, Selfish = 187
# Step 21: Total = 313, Altruistic = 120, Selfish = 193
# Step 22: Total = 323, Altruistic = 120, Selfish = 203
# Step 23: Total = 326, Altruistic = 120, Selfish = 206
# Step 24: Total = 333, Altruistic = 120, Selfish = 213
# Step 25: Total = 342, Altruistic = 120, Selfish = 222
# Step 26: Total = 351, Altruistic = 120, Selfish = 231
# Step 27: Total = 367, Altruistic = 120, Selfish = 247
# Step 28: Total = 382, Altruistic = 120, Selfish = 262
# Step 29: Total = 390, Altruistic = 120, Selfish = 270
# Step 30: Total = 398, Altruistic = 120, Selfish = 278
# Step 31: Total = 404, Altruistic = 118, Selfish = 286
# Step 32: Total = 414, Altruistic = 118, Selfish = 296
# Step 33: Total = 416, Altruistic = 114, Selfish = 302
# Step 34: Total = 418, Altruistic = 111, Selfish = 307
# Step 35: Total = 407, Altruistic = 100, Selfish = 307
# Step 36: Total = 402, Altruistic = 97, Selfish = 305
# Step 37: Total = 385, Altruistic = 84, Selfish = 301
# Step 38: Total = 367, Altruistic = 73, Selfish = 294
# Step 39: Total = 317, Altruistic = 61, Selfish = 256
# Step 40: Total = 270, Altruistic = 54, Selfish = 216
# Step 41: Total = 247, Altruistic = 51, Selfish = 196
# Step 42: Total = 233, Altruistic = 49, Selfish = 184
# Step 43: Total = 230, Altruistic = 48, Selfish = 182
# Step 44: Total = 237, Altruistic = 48, Selfish = 189
# Step 45: Total = 240, Altruistic = 48, Selfish = 192
# Step 46: Total = 247, Altruistic = 48, Selfish = 199
# Step 47: Total = 255, Altruistic = 48, Selfish = 207
# Step 48: Total = 259, Altruistic = 48, Selfish = 211
# Step 49: Total = 262, Altruistic = 48, Selfish = 214
# Step 50: Total = 263, Altruistic = 48, Selfish = 215
# Step 51: Total = 263, Altruistic = 48, Selfish = 215
# Step 52: Total = 266, Altruistic = 48, Selfish = 218
# Step 53: Total = 279, Altruistic = 48, Selfish = 231
# Step 54: Total = 282, Altruistic = 48, Selfish = 234
# Step 55: Total = 286, Altruistic = 48, Selfish = 238
# Step 56: Total = 293, Altruistic = 48, Selfish = 245
# Step 57: Total = 302, Altruistic = 48, Selfish = 254
# Step 58: Total = 312, Altruistic = 48, Selfish = 264
# Step 59: Total = 320, Altruistic = 48, Selfish = 272
# Step 60: Total = 342, Altruistic = 48, Selfish = 294
# Step 61: Total = 357, Altruistic = 48, Selfish = 309
# Step 62: Total = 377, Altruistic = 47, Selfish = 330
# Step 63: Total = 387, Altruistic = 46, Selfish = 341
# Step 64: Total = 401, Altruistic = 46, Selfish = 355
# Step 65: Total = 427, Altruistic = 46, Selfish = 381
# Step 66: Total = 442, Altruistic = 44, Selfish = 398
# Step 67: Total = 465, Altruistic = 43, Selfish = 422
# Step 68: Total = 480, Altruistic = 41, Selfish = 439
# Step 69: Total = 492, Altruistic = 37, Selfish = 455
# Step 70: Total = 512, Altruistic = 37, Selfish = 475
# Step 71: Total = 535, Altruistic = 37, Selfish = 498
# Step 72: Total = 547, Altruistic = 34, Selfish = 513
# Step 73: Total = 564, Altruistic = 31, Selfish = 533
# Step 74: Total = 590, Altruistic = 30, Selfish = 560
# Step 75: Total = 618, Altruistic = 29, Selfish = 589
# Step 76: Total = 638, Altruistic = 26, Selfish = 612
# Step 77: Total = 661, Altruistic = 25, Selfish = 636
# Step 78: Total = 680, Altruistic = 25, Selfish = 655
# Step 79: Total = 701, Altruistic = 24, Selfish = 677
# Step 80: Total = 730, Altruistic = 23, Selfish = 707
# Step 81: Total = 748, Altruistic = 22, Selfish = 726
# Step 82: Total = 771, Altruistic = 22, Selfish = 749
# Step 83: Total = 808, Altruistic = 22, Selfish = 786
# Step 84: Total = 832, Altruistic = 19, Selfish = 813
# Step 85: Total = 860, Altruistic = 19, Selfish = 841
# Step 86: Total = 883, Altruistic = 15, Selfish = 868
# Step 87: Total = 880, Altruistic = 14, Selfish = 866
# Step 88: Total = 875, Altruistic = 13, Selfish = 862
# Step 89: Total = 869, Altruistic = 11, Selfish = 858
# Step 90: Total = 862, Altruistic = 10, Selfish = 852
# Step 91: Total = 861, Altruistic = 9, Selfish = 852
# Step 92: Total = 857, Altruistic = 8, Selfish = 849
# Step 93: Total = 851, Altruistic = 7, Selfish = 844
# Step 94: Total = 848, Altruistic = 6, Selfish = 842
# Step 95: Total = 845, Altruistic = 5, Selfish = 840
# Step 96: Total = 840, Altruistic = 5, Selfish = 835
# Step 97: Total = 835, Altruistic = 4, Selfish = 831
# Step 98: Total = 828, Altruistic = 3, Selfish = 825
# Step 99: Total = 785, Altruistic = 2, Selfish = 783
# Step 100: Total = 663, Altruistic = 1, Selfish = 662
# Step 101: Total = 471, Altruistic = 0, Selfish = 471
# Step 102: Total = 346, Altruistic = 0, Selfish = 346
# Step 103: Total = 268, Altruistic = 0, Selfish = 268
# Step 104: Total = 207, Altruistic = 0, Selfish = 207
# Step 105: Total = 168, Altruistic = 0, Selfish = 168
# Step 106: Total = 154, Altruistic = 0, Selfish = 154
# Step 107: Total = 140, Altruistic = 0, Selfish = 140
# Step 108: Total = 125, Altruistic = 0, Selfish = 125
# Step 109: Total = 118, Altruistic = 0, Selfish = 118
# Step 110: Total = 118, Altruistic = 0, Selfish = 118
# Step 111: Total = 117, Altruistic = 0, Selfish = 117
# Step 112: Total = 115, Altruistic = 0, Selfish = 115
# Step 113: Total = 113, Altruistic = 0, Selfish = 113
# Step 114: Total = 112, Altruistic = 0, Selfish = 112
# Step 115: Total = 111, Altruistic = 0, Selfish = 111
# Step 116: Total = 108, Altruistic = 0, Selfish = 108
# Step 117: Total = 106, Altruistic = 0, Selfish = 106
# Step 118: Total = 106, Altruistic = 0, Selfish = 106
# Step 119: Total = 107, Altruistic = 0, Selfish = 107
# Step 120: Total = 116, Altruistic = 0, Selfish = 116
# Step 121: Total = 116, Altruistic = 0, Selfish = 116
# Step 122: Total = 116, Altruistic = 0, Selfish = 116
# Step 123: Total = 112, Altruistic = 0, Selfish = 112
# Step 124: Total = 111, Altruistic = 0, Selfish = 111
# Step 125: Total = 109, Altruistic = 0, Selfish = 109
# Step 126: Total = 107, Altruistic = 0, Selfish = 107
# Step 127: Total = 107, Altruistic = 0, Selfish = 107
# Step 128: Total = 105, Altruistic = 0, Selfish = 105
# Step 129: Total = 104, Altruistic = 0, Selfish = 104
# Step 130: Total = 104, Altruistic = 0, Selfish = 104
# Step 131: Total = 101, Altruistic = 0, Selfish = 101
# Step 132: Total = 99, Altruistic = 0, Selfish = 99
# Step 133: Total = 97, Altruistic = 0, Selfish = 97
# Step 134: Total = 93, Altruistic = 0, Selfish = 93
# Step 135: Total = 92, Altruistic = 0, Selfish = 92
# Step 136: Total = 92, Altruistic = 0, Selfish = 92
# Step 137: Total = 90, Altruistic = 0, Selfish = 90
# Step 138: Total = 86, Altruistic = 0, Selfish = 86
# Step 139: Total = 84, Altruistic = 0, Selfish = 84
# Step 140: Total = 82, Altruistic = 0, Selfish = 82
# Step 141: Total = 79, Altruistic = 0, Selfish = 79
# Step 142: Total = 78, Altruistic = 0, Selfish = 78
# Step 143: Total = 75, Altruistic = 0, Selfish = 75
# Step 144: Total = 72, Altruistic = 0, Selfish = 72
# Step 145: Total = 70, Altruistic = 0, Selfish = 70
# Step 146: Total = 68, Altruistic = 0, Selfish = 68
# Step 147: Total = 65, Altruistic = 0, Selfish = 65
# Step 148: Total = 64, Altruistic = 0, Selfish = 64
# Step 149: Total = 63, Altruistic = 0, Selfish = 63
# Step 150: Total = 61, Altruistic = 0, Selfish = 61
# Step 151: Total = 57, Altruistic = 0, Selfish = 57
# Step 152: Total = 55, Altruistic = 0, Selfish = 55
# Step 153: Total = 53, Altruistic = 0, Selfish = 53
# Step 154: Total = 52, Altruistic = 0, Selfish = 52
# Step 155: Total = 54, Altruistic = 0, Selfish = 54
# Step 156: Total = 58, Altruistic = 0, Selfish = 58
# Step 157: Total = 56, Altruistic = 0, Selfish = 56
# Step 158: Total = 60, Altruistic = 0, Selfish = 60
# Step 159: Total = 61, Altruistic = 0, Selfish = 61
# Step 160: Total = 63, Altruistic = 0, Selfish = 63
# Step 161: Total = 62, Altruistic = 0, Selfish = 62
# Step 162: Total = 62, Altruistic = 0, Selfish = 62
# Step 163: Total = 60, Altruistic = 0, Selfish = 60
# Step 164: Total = 58, Altruistic = 0, Selfish = 58
# Step 165: Total = 54, Altruistic = 0, Selfish = 54
# Step 166: Total = 54, Altruistic = 0, Selfish = 54
# Step 167: Total = 52, Altruistic = 0, Selfish = 52
# Step 168: Total = 49, Altruistic = 0, Selfish = 49
# Step 169: Total = 49, Altruistic = 0, Selfish = 49
# Step 170: Total = 48, Altruistic = 0, Selfish = 48
# Step 171: Total = 45, Altruistic = 0, Selfish = 45
# Step 172: Total = 44, Altruistic = 0, Selfish = 44
# Step 173: Total = 42, Altruistic = 0, Selfish = 42
# Step 174: Total = 40, Altruistic = 0, Selfish = 40
# Step 175: Total = 40, Altruistic = 0, Selfish = 40
# Step 176: Total = 39, Altruistic = 0, Selfish = 39
# Step 177: Total = 37, Altruistic = 0, Selfish = 37
# Step 178: Total = 34, Altruistic = 0, Selfish = 34
# Step 179: Total = 34, Altruistic = 0, Selfish = 34
# Step 180: Total = 34, Altruistic = 0, Selfish = 34
# Step 181: Total = 33, Altruistic = 0, Selfish = 33
# Step 182: Total = 33, Altruistic = 0, Selfish = 33
# Step 183: Total = 32, Altruistic = 0, Selfish = 32
# Step 184: Total = 28, Altruistic = 0, Selfish = 28
# Step 185: Total = 25, Altruistic = 0, Selfish = 25
# Step 186: Total = 25, Altruistic = 0, Selfish = 25
# Step 187: Total = 17, Altruistic = 0, Selfish = 17
# Step 188: Total = 15, Altruistic = 0, Selfish = 15
# Step 189: Total = 11, Altruistic = 0, Selfish = 11
# Step 190: Total = 11, Altruistic = 0, Selfish = 11
# Step 191: Total = 7, Altruistic = 0, Selfish = 7
# Step 192: Total = 7, Altruistic = 0, Selfish = 7
# Step 193: Total = 7, Altruistic = 0, Selfish = 7
# Step 194: Total = 4, Altruistic = 0, Selfish = 4
# Step 195: Total = 2, Altruistic = 0, Selfish = 2
# Step 196: Total = 2, Altruistic = 0, Selfish = 2
# Step 197: Total = 2, Altruistic = 0, Selfish = 2
# Step 198: Total = 1, Altruistic = 0, Selfish = 1
# Step 199: Total = 1, Altruistic = 0, Selfish = 1
# Step 200: Total = 1, Altruistic = 0, Selfish = 1
# Step 201: Total = 1, Altruistic = 0, Selfish = 1
# Step 202: Total = 1, Altruistic = 0, Selfish = 1
# Step 203: Total = 1, Altruistic = 0, Selfish = 1
#
# Simulation 5:
# Step 0: Total = 400, Altruistic = 180, Selfish = 220
# Step 1: Total = 400, Altruistic = 180, Selfish = 220
# Step 2: Total = 399, Altruistic = 179, Selfish = 220
# Step 3: Total = 394, Altruistic = 175, Selfish = 219
# Step 4: Total = 393, Altruistic = 175, Selfish = 218
# Step 5: Total = 392, Altruistic = 174, Selfish = 218
# Step 6: Total = 390, Altruistic = 173, Selfish = 217
# Step 7: Total = 385, Altruistic = 171, Selfish = 214
# Step 8: Total = 385, Altruistic = 171, Selfish = 214
# Step 9: Total = 385, Altruistic = 171, Selfish = 214
# Step 10: Total = 385, Altruistic = 171, Selfish = 214
# Step 11: Total = 385, Altruistic = 171, Selfish = 214
# Step 12: Total = 424, Altruistic = 171, Selfish = 253
# Step 13: Total = 440, Altruistic = 171, Selfish = 269
# Step 14: Total = 441, Altruistic = 171, Selfish = 270
# Step 15: Total = 441, Altruistic = 171, Selfish = 270
# Step 16: Total = 441, Altruistic = 171, Selfish = 270
# Step 17: Total = 439, Altruistic = 171, Selfish = 268
# Step 18: Total = 439, Altruistic = 171, Selfish = 268
# Step 19: Total = 438, Altruistic = 170, Selfish = 268
# Step 20: Total = 438, Altruistic = 170, Selfish = 268
# Step 21: Total = 435, Altruistic = 167, Selfish = 268
# Step 22: Total = 428, Altruistic = 160, Selfish = 268
# Step 23: Total = 419, Altruistic = 151, Selfish = 268
# Step 24: Total = 394, Altruistic = 127, Selfish = 267
# Step 25: Total = 359, Altruistic = 95, Selfish = 264
# Step 26: Total = 284, Altruistic = 62, Selfish = 222
# Step 27: Total = 198, Altruistic = 26, Selfish = 172
# Step 28: Total = 135, Altruistic = 13, Selfish = 122
# Step 29: Total = 78, Altruistic = 3, Selfish = 75
# Step 30: Total = 44, Altruistic = 0, Selfish = 44
# Step 31: Total = 28, Altruistic = 0, Selfish = 28
# Step 32: Total = 16, Altruistic = 0, Selfish = 16
# Step 33: Total = 7, Altruistic = 0, Selfish = 7
# Step 34: Total = 4, Altruistic = 0, Selfish = 4
# Step 35: Total = 4, Altruistic = 0, Selfish = 4
# Step 36: Total = 4, Altruistic = 0, Selfish = 4
# Step 37: Total = 4, Altruistic = 0, Selfish = 4
# Step 38: Total = 3, Altruistic = 0, Selfish = 3
# Step 39: Total = 3, Altruistic = 0, Selfish = 3
# Step 40: Total = 3, Altruistic = 0, Selfish = 3
# Step 41: Total = 2, Altruistic = 0, Selfish = 2
# Step 42: Total = 1, Altruistic = 0, Selfish = 1
# Step 43: Total = 1, Altruistic = 0, Selfish = 1
# Step 44: Total = 1, Altruistic = 0, Selfish = 1
# Step 45: Total = 1, Altruistic = 0, Selfish = 1
# Step 46: Total = 1, Altruistic = 0, Selfish = 1
# Step 47: Total = 1, Altruistic = 0, Selfish = 1
# Step 48: Total = 1, Altruistic = 0, Selfish = 1
# Step 49: Total = 1, Altruistic = 0, Selfish = 1
# Step 50: Total = 1, Altruistic = 0, Selfish = 1
# Step 51: Total = 1, Altruistic = 0, Selfish = 1
# Step 52: Total = 1, Altruistic = 0, Selfish = 1
# Step 53: Total = 1, Altruistic = 0, Selfish = 1
# Step 54: Total = 1, Altruistic = 0, Selfish = 1
# Step 55: Total = 1, Altruistic = 0, Selfish = 1
# Step 56: Total = 1, Altruistic = 0, Selfish = 1
# Step 57: Total = 1, Altruistic = 0, Selfish = 1
# Step 58: Total = 1, Altruistic = 0, Selfish = 1
# Step 59: Total = 1, Altruistic = 0, Selfish = 1
# Step 60: Total = 1, Altruistic = 0, Selfish = 1
# Step 61: Total = 1, Altruistic = 0, Selfish = 1
# Step 62: Total = 1, Altruistic = 0, Selfish = 1
# Step 63: Total = 1, Altruistic = 0, Selfish = 1
# Step 64: Total = 1, Altruistic = 0, Selfish = 1
# Step 65: Total = 1, Altruistic = 0, Selfish = 1
# Step 66: Total = 1, Altruistic = 0, Selfish = 1
# Step 67: Total = 1, Altruistic = 0, Selfish = 1
# The experiment took 7.04 minutes to complete.

# %%
# List all available Configuration IDs
# print("Available Configuration IDs:", list(experiment.data_collections.keys()))
print("Total Available Configurations:", len(experiment.data_collections.keys()))

# %%
# Access the DataCollection instance for the chosen configuration
# Choose a configuration ID to examine
config_id_to_check = 'Eco-0-0-0_Disease-0-0-0'  # Example configuration ID

# Access the DataCollection instance for the chosen configuration from your Experiment instance
data_collector = experiment.data_collections[config_id_to_check]

if config_id_to_check in data_collector.data:
    # Population Data
    population_data = data_collector.data[config_id_to_check]['population_data']
    plt.figure(figsize=(10, 6))
    sns.lineplot(data=population_data, x='Timestep', y='Population', hue='Type', style='Type', markers=True, dashes=False, estimator='mean', ci='sd')
    plt.title('Population Over Time with Mean and Standard Deviation')
    plt.xlabel('Timestep')
    plt.ylabel('Population')
    plt.legend(title='Agent Type')
    plt.grid(True)
    plt.show()

    # Metabolism Data
    metabolism_data = data_collector.data[config_id_to_check]['metabolism_data']
    plt.figure(figsize=(10, 6))
    sns.lineplot(data=metabolism_data, x='Timestep', y='Metabolism', hue='Type', style='Type', markers=True, dashes=False, estimator='mean', ci='sd')
    plt.title('Metabolism Over Time with Mean and Standard Deviation')
    plt.xlabel('Timestep')
    plt.ylabel('Metabolism')
    plt.legend(title='Agent Type')
    plt.grid(True)
    plt.show()

    # Vision Data
    vision_data = data_collector.data[config_id_to_check]['vision_data']
    plt.figure(figsize=(10, 6))
    sns.lineplot(data=vision_data, x='Timestep', y='Vision', hue='Type', style='Type', markers=True, dashes=False, estimator='mean', ci='sd')
    plt.title('Vision Over Time with Mean and Standard Deviation')
    plt.xlabel('Timestep')
    plt.ylabel('Vision')
    plt.legend(title='Agent Type')
    plt.grid(True)
    plt.show()

    # Wealth Data
    wealth_data = data_collector.data[config_id_to_check]['wealth_data']
    plt.figure(figsize=(10, 6))
    sns.lineplot(data=wealth_data, x='Timestep', y='Wealth', hue='Type', style='Type', markers=True, dashes=False, estimator='mean', ci='sd')
    plt.title('Wealth Over Time with Mean and Standard Deviation')
    plt.xlabel('Timestep')
    plt.ylabel('Wealth')
    plt.legend(title='Agent Type')
    plt.grid(True)
    plt.show()

else:
    print("No data available for this configuration ID.")

# %%
# Assuming 'age_distribution' is structured with columns ['Timestep', 'Age', 'Count', 'Type']
age_data = data_collector.data[config_id_to_check]['age_distribution']

if not age_data.empty and age_data['Count'].sum() > 0:
    # Ensure proper data types
    age_data['Age'] = pd.to_numeric(age_data['Age'], errors='coerce')
    age_data['Count'] = pd.to_numeric(age_data['Count'], errors='coerce')
    age_data.dropna(subset=['Age', 'Count'], inplace=True)  # Drop rows where 'Age' or 'Count' could not be converted

    # Calculate the weighted age and group by Timestep and Type
    age_data['Weighted_Age'] = age_data['Age'] * age_data['Count']
    grouped = age_data.groupby(['Timestep', 'Type']).agg(
        Total_Count=('Count', 'sum'),
        Sum_Weighted_Age=('Weighted_Age', 'sum')
    )

    # Calculate the average age for each agent type
    grouped['Average_Age'] = grouped['Sum_Weighted_Age'] / grouped['Total_Count']

    # Calculate variance for standard deviation
    age_data = age_data.merge(grouped[['Average_Age']], on=['Timestep', 'Type'])
    age_data['Variance_Term'] = age_data['Count'] * (age_data['Age'] - age_data['Average_Age'])**2
    variance_grouped = age_data.groupby(['Timestep', 'Type'])['Variance_Term'].sum() / grouped['Total_Count']
    grouped['Std_Dev_Age'] = variance_grouped.apply(lambda x: np.sqrt(x) if x >= 0 else 0)

    # Reset index for plotting
    final_data = grouped.reset_index()

    # Plotting with standard deviation
    plt.figure(figsize=(10, 6))
    sns.lineplot(data=final_data, x='Timestep', y='Average_Age', hue='Type', marker='o', style='Type')
    for _, row in final_data.iterrows():
        plt.fill_betweenx([row['Average_Age'] - row['Std_Dev_Age'], row['Average_Age'] + row['Std_Dev_Age']], row['Timestep'] - 0.2, row['Timestep'] + 0.2, color='blue', alpha=0.2)
    plt.title('Average Age Over Time with Standard Deviation by Agent Type')
    plt.xlabel('Timestep')
    plt.ylabel('Average Age')
    plt.legend(title='Agent Type')
    plt.grid(True)
    plt.show()
else:
    print("No age data available for plotting.")

# %%
# Assuming 'infection_data' is structured with columns ['Timestep', 'Infections', 'Recoveries', 'Type']
infection_data = data_collector.data[config_id_to_check]['infection_data']

if not infection_data.empty and (infection_data['Infections'].sum() > 0 or infection_data['Recoveries'].sum() > 0):
    plt.figure(figsize=(10, 6))
    # Plotting the data for infections and recoveries separately by agent type
    sns.lineplot(data=infection_data, x='Timestep', y='Infections', hue='Type', style='Type', markers=True, dashes=False, palette='viridis')
    sns.lineplot(data=infection_data, x='Timestep', y='Recoveries', hue='Type', style='Type', markers=True, dashes=False, palette='viridis')
    plt.title('Infection and Recovery Over Time by Agent Type')
    plt.xlabel('Timestep')
    plt.ylabel('Count')
    plt.legend(title='Type')
    plt.grid(True)
    plt.show()
else:
    print("No infection data available for plotting.")

# %%
# Assuming you've chosen a specific configuration ID and have data available
wealth_data = data_collector.data[config_id_to_check]['wealth_data']

# Check if there's wealth data to plot
if not wealth_data.empty:
    # Define the steps you want to plot
    total_steps = wealth_data['Timestep'].max() + 1  # Assuming continuous steps from 0 to max
    step_skip = 31  # Define the number of steps to skip between plots
    steps_to_plot = range(0, total_steps, step_skip)
    steps_to_plot = list(steps_to_plot)[:9]  # Take only the first 9 steps to fit a 3x3 grid

    # Setting up the subplot grid
    fig, axes = plt.subplots(3, 3, figsize=(15, 12))
    axes = axes.flatten()  # Flatten the 2D array of axes to iterate easily

    # Plot histograms for each selected timestep, filtering by type
    for i, step in enumerate(steps_to_plot):
        # Filter the data for the current step and each type
        data_at_step = wealth_data[wealth_data['Timestep'] == step]
        sns.histplot(data=data_at_step, x='Wealth', hue='Type', ax=axes[i], kde=True, palette='viridis', bins=25, element='step', stat='density')
        axes[i].set_title(f'Wealth Distribution at Timestep {step}')
        axes[i].set_xlabel('Wealth')
        axes[i].set_ylabel('Density')

    # Adjust layout to prevent overlap
    plt.tight_layout()
    plt.show()
else:
    print("No wealth data available for plotting.")

# %%
# Assuming you've chosen a specific configuration ID and have data available
wealth_data = data_collector.data[config_id_to_check]['wealth_data']

# Check if there's wealth data to plot
if not wealth_data.empty:
    # Define the steps you want to plot
    total_steps = wealth_data['Timestep'].max() + 1  # Assuming continuous steps from 0 to max
    step_skip = 31  # Define the number of steps to skip between plots
    steps_to_plot = range(0, total_steps, step_skip)
    steps_to_plot = list(steps_to_plot)[:9]  # Take only the first 9 steps to fit a 3x3 grid

    # Setting up the subplot grid
    fig, axes = plt.subplots(3, 3, figsize=(15, 12))
    axes = axes.flatten()  # Flatten the 2D array of axes to iterate easily

    # Plot Lorenz curves and calculate Gini index for each selected timestep
    for i, step in enumerate(steps_to_plot):
        # Filter the data for the current step
        data_at_step = wealth_data[wealth_data['Timestep'] == step]
        if data_at_step.empty:
            axes[i].text(0.5, 0.5, 'No data available', horizontalalignment='center', verticalalignment='center', transform=axes[i].transAxes)
            axes[i].set_title(f'Timestep {step}')
            continue

        for type in data_at_step['Type'].unique():
            # Filter data by type
            type_data = data_at_step[data_at_step['Type'] == type]['Wealth']

            # Sort data and normalize
            sorted_wealth = np.sort(type_data)
            cumulative_wealth = np.cumsum(sorted_wealth)
            total_wealth = cumulative_wealth[-1]
            normalized_wealth = cumulative_wealth / total_wealth

            # Create Lorenz curve points
            x = np.linspace(0, 1, len(sorted_wealth) + 1)  # Include zero point
            y = np.concatenate([[0], normalized_wealth])  # Include the zero point to start the curve

            # Plot the curve
            axes[i].plot(x, y, label=f'Lorenz Curve - {type}')
            axes[i].plot([0, 1], [0, 1], 'k--', label='Line of Equality')

            # Calculate and annotate Gini index
            gini_index = 1 - 2 * np.trapz(y, x)
            axes[i].set_title(f'Wealth Distribution at Timestep {step}\nGini Index for {type}: {gini_index:.2f}')

        axes[i].set_xlabel('Fraction of Population')
        axes[i].set_ylabel('Fraction of Wealth')
        axes[i].legend()

    # Adjust layout to prevent overlap
    plt.tight_layout()
    plt.show()
else:
    print("No wealth data available for plotting.")

# %%
def calculate_gini(arr):
    """Calculate the Gini coefficient of a numpy array."""
    # Ensure array is sorted.
    arr = np.sort(arr)
    n = arr.size
    cumulative_sum = np.cumsum(arr)
    # Compute the Lorenz curve using the cumulative sum.
    lorenz_curve = cumulative_sum / cumulative_sum[-1]
    # Linear space to represent population share
    uniform_distribution = np.linspace(0, 1, n+1)
    # Gini index calculation using trapezoidal rule
    area_under_lorenz = np.trapz(lorenz_curve, uniform_distribution[1:])
    area_under_uniform = 0.5
    gini_index = (area_under_uniform - area_under_lorenz) / area_under_uniform
    return gini_index

# Assuming 'wealth_data' is a DataFrame with columns ['Timestep', 'Wealth', 'Type']
# Check if there's wealth data for the initial timestep and calculate Gini indices for each type
initial_wealth = wealth_data[wealth_data['Timestep'] == 0]

if not initial_wealth.empty:
    for agent_type in initial_wealth['Type'].unique():
        type_specific_wealth = initial_wealth[initial_wealth['Type'] == agent_type]['Wealth']
        gini_index = calculate_gini(type_specific_wealth.values)
        print(f"Gini Index at Step 0 for {agent_type} agents:", gini_index)
else:
    print("No wealth data available for Gini calculation.")

# %%
np.random.seed(42)

environment = Environment(size=(50, 50), max_capacity=6, enable_seasons=False, tau=0.2, d=0)

eco_crisis = EcoCrisis(severity=0, duration=0, frequency=0)
disease = Disease(severity=0, duration=0, frequency=0)

environment.trigger_crisis(eco_crisis)
environment.trigger_disease(disease)

occupied_locations = set()
for _ in range(400):
    while True:
        location = (np.random.randint(0, 50), np.random.randint(0, 50))
        if location not in occupied_locations:
            occupied_locations.add(location)
            break
    vision = np.random.randint(1, 7)
    metabolism = np.random.randint(1, 5)
    sugar = np.random.randint(5, 26)
    age = np.random.randint(60, 101)
    agent = Agent(location=location, sugar=sugar, metabolism=metabolism, vision=vision, max_age=age)
    environment.add_agent(agent)

environment.capture_agents_initial_data()

# Run the simulation for 250 steps
for step in range(250):
    environment.step()

    # Print the agent counts from agent_history and calculate average traits
    agent_history = environment.agents_history[-1]
    total_count = len(agent_history)
    altruistic_count = len([agent for agent in agent_history if agent[1] == 'altruistic'])
    selfish_count = len([agent for agent in agent_history if agent[1] == 'selfish'])

    # Calculate average traits for all agents
    if total_count > 0:
        avg_sugar = sum(agent[2] for agent in agent_history) / total_count
        avg_metabolism = sum(agent[3] for agent in agent_history) / total_count
        avg_vision = sum(agent[4] for agent in agent_history) / total_count
        avg_age = sum(agent[5] for agent in agent_history) / total_count
    else:
        avg_sugar = avg_metabolism = avg_vision = avg_age = 0

    print(f"Step {step}: Total agents: {total_count}, Altruistic agents: {altruistic_count}, Selfish agents: {selfish_count}")
    print(f"Step {step}: Avg sugar: {avg_sugar:.2f}, Avg metabolism: {avg_metabolism:.2f}, Avg vision: {avg_vision:.2f}, Avg age: {avg_age:.2f}")

visualization = Visualization(environment)
anim = visualization.animate_simulation(interval=200)
HTML(anim.to_jshtml())
